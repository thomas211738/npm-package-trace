# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import requests
import sys
import csv
import time
from urllib.parse import quote

# %%
def get_top_npm_packages():
    """
    Fetches the top 5,000 most downloaded npm packages from the Hugging Face API
    and saves them to a CSV file with all available data fields.
    """
    base_url = "https://datasets-server.huggingface.co/rows?dataset=deepklarity%2Ftop-npm-packages&config=default&split=train&length=100"
    all_packages = []
    
    try:
        # The API returns 100 packages per request, so we loop 10 times to get 5000.
        print("Fetching package data...", file=sys.stderr)
        for offset in range(0, 5000, 100):
            url = f"{base_url}&offset={offset}"
            
            # Fetch the data from the API
            response = requests.get(url)
            response.raise_for_status()  # Raise an exception for bad status codes
            
            data = response.json()
            rows = data.get('rows', [])
            
            # Extract the package data from the 'row' key in each item
            for item in rows:
                if 'row' in item:
                    all_packages.append(item['row'])
            
            print(f"Fetched {len(all_packages)} packages...", file=sys.stderr)
            # A small delay to be respectful to the API
            time.sleep(0.1)

        if not all_packages:
            print("No packages were found.", file=sys.stderr)
            return

        # Sort packages by weekly_downloads in descending order
        sorted_packages = sorted(all_packages, key=lambda x: x.get('weekly_downloads', 0), reverse=True)
        
        # Define the output filename
        filename = "top_5000_npm_packages.csv"
        
        # Get headers from the keys of the first package object
        headers = list(sorted_packages[0].keys())

        # Save the data to a CSV file
        with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(headers) # Write the header row
            
            # Write the top 1,000 packages to the CSV file
            for pkg in sorted_packages[:5000]:
                # Write a row for each package, getting values for each header
                writer.writerow([pkg.get(header) for header in headers])

        print(f"\nSuccessfully saved data for {len(sorted_packages)} packages to {filename}", file=sys.stderr)
            
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}", file=sys.stderr)
    except (ValueError, KeyError, IndexError) as e:
        print(f"Error processing data: {e}", file=sys.stderr)

# %%
get_top_npm_packages()
# Out:
# Fetching package data...
# Fetched 100 packages...
# Fetched 200 packages...
# Fetched 300 packages...
# Fetched 400 packages...
# Fetched 500 packages...
# Fetched 600 packages...
# Fetched 700 packages...
# Fetched 800 packages...
# Fetched 900 packages...
# Fetched 1000 packages...
# Fetched 1100 packages...
# Fetched 1200 packages...
# Fetched 1300 packages...
# Fetched 1400 packages...
# Fetched 1500 packages...
# Fetched 1600 packages...
# Fetched 1700 packages...
# Fetched 1800 packages...
# Fetched 1900 packages...
# Fetched 2000 packages...
# Fetched 2100 packages...
# Fetched 2200 packages...
# Fetched 2300 packages...
# Fetched 2400 packages...
# Fetched 2500 packages...
# Fetched 2600 packages...
# Fetched 2700 packages...
# Fetched 2800 packages...
# Fetched 2900 packages...
# Fetched 3000 packages...
# Fetched 3100 packages...
# Fetched 3200 packages...
# Fetched 3300 packages...
# Fetched 3400 packages...
# Fetched 3500 packages...
# Fetched 3600 packages...
# Fetched 3700 packages...
# Fetched 3800 packages...
# Fetched 3900 packages...
# Fetched 4000 packages...
# Fetched 4100 packages...
# Fetched 4200 packages...
# Fetched 4300 packages...
# Fetched 4400 packages...
# Fetched 4500 packages...
# Fetched 4600 packages...
# Fetched 4700 packages...
# Fetched 4800 packages...
# Fetched 4900 packages...
# Fetched 5000 packages...
#
# Successfully saved data for 5000 packages to top_5000_npm_packages.csv

# %%
def get_package_dependencies(package_name):
    """
    Fetch dependencies and devDependencies for a given npm package.
    
    Args:
        package_name (str): Name of the npm package
        
    Returns:
        tuple: (dependencies_list, devDependencies_list)
    """
    try:
        # URL encode the package name (handles both scoped and regular packages)
        encoded_name = quote(package_name, safe='')
        url = f"https://api.npms.io/v2/package/{encoded_name}"
        
        # Make the API request
        response = requests.get(url, timeout=10)
        
        # Check if request was successful
        if response.status_code == 200:
            data = response.json()
            
            # Extract dependencies from the collected.metadata section
            metadata = data.get('collected', {}).get('metadata', {})
            dependencies = metadata.get('dependencies', {})
            dev_dependencies = metadata.get('devDependencies', {})
            
            dependencies_list = list(dependencies.keys()) if dependencies else []
            devDependencies_list = list(dev_dependencies.keys()) if dev_dependencies else []
            
            return (dependencies_list, devDependencies_list)
        else:
            print(f"  Error: HTTP {response.status_code}")
            return ([], [])
            
    except requests.exceptions.Timeout:
        print(f"  Error: Timeout")
        return ([], [])
    except Exception as e:
        print(f"  Error: {str(e)}")
        return ([], [])

# %%
df = pd.read_csv('top_5000_npm_packages.csv') 

if 'dependencies_list' not in df.columns:
    df['dependencies_list'] = None
if 'devDependencies_list' not in df.columns:
    df['devDependencies_list'] = None

# Process each package and save after every iteration
for idx in df.index:
    package_name = df.loc[idx, 'package_name']
    
    # Skip if already processed (in case of resuming after timeout)
    if pd.notna(df.loc[idx, 'dependencies_list']) and df.loc[idx, 'dependencies_list'] != '':
        print(f"Skipping {idx + 1}/{len(df)}: {package_name} (already processed)")
        continue
    
    print(f"Processing {idx + 1}/{len(df)}: {package_name}")
    
    # Get dependencies
    deps_list, dev_deps_list = get_package_dependencies(package_name)
    
    # Update the dataframe
    df.loc[idx, 'dependencies_list'] = str(deps_list)
    df.loc[idx, 'devDependencies_list'] = str(dev_deps_list)
    
    # Save to CSV after each iteration
    df.to_csv('top_5000_npm_packages.csv', index=False)
    
    # Add a small delay to be respectful to the API
    if idx < df.index[-1]:  # Don't sleep after the last item
        time.sleep(0.5)  # 500ms delay between requests

print("\nProcessing complete!")
print(f"Results saved to top_5000_npm_packages.csv")
# Out:
# Processing 1/5000: ansi-styles
# Processing 2/5000: supports-color
# Processing 3/5000: semver
# Processing 4/5000: chalk
# Processing 5/5000: debug
# Processing 6/5000: has-flag
# Processing 7/5000: color-convert
# Processing 8/5000: color-name
# Processing 9/5000: tslib
# Processing 10/5000: ms
# Processing 11/5000: minimatch
# Processing 12/5000: strip-ansi
# Processing 13/5000: lru-cache
# Processing 14/5000: type-fest
# Processing 15/5000: ansi-regex
# Processing 16/5000: source-map
# Processing 17/5000: glob
# Processing 18/5000: commander
# Processing 19/5000: readable-stream
# Processing 20/5000: string-width
# Processing 21/5000: brace-expansion
# Processing 22/5000: escape-string-regexp
# Processing 23/5000: wrap-ansi
# Processing 24/5000: find-up
# Processing 25/5000: yallist
# Processing 26/5000: p-locate
# Processing 27/5000: locate-path
# Processing 28/5000: p-limit
# Processing 29/5000: emoji-regex
# Processing 30/5000: safe-buffer
# Processing 31/5000: uuid
# Processing 32/5000: minipass
# Processing 33/5000: @types/node
# Processing 34/5000: ajv
# Processing 35/5000: string_decoder
# Processing 36/5000: react-is
# Processing 37/5000: isarray
# Processing 38/5000: is-fullwidth-code-point
# Processing 39/5000: fs-extra
# Processing 40/5000: get-stream
# Processing 41/5000: kind-of
# Processing 42/5000: json-schema-traverse
# Processing 43/5000: yargs-parser
# Processing 44/5000: which
# Processing 45/5000: glob-parent
# Processing 46/5000: yargs
# Processing 47/5000: acorn
# Processing 48/5000: rimraf
# Processing 49/5000: globals
# Processing 50/5000: js-yaml
# Processing 51/5000: argparse
# Processing 52/5000: signal-exit
# Processing 53/5000: cliui
# Processing 54/5000: estraverse
# Processing 55/5000: path-exists
# Processing 56/5000: pretty-format
# Processing 57/5000: resolve-from
# Processing 58/5000: execa
# Processing 59/5000: camelcase
# Processing 60/5000: is-stream
# Processing 61/5000: path-key
# Processing 62/5000: schema-utils
# Processing 63/5000: ws
# Processing 64/5000: punycode
# Processing 65/5000: universalify
# Processing 66/5000: slash
# Processing 67/5000: mkdirp
# Processing 68/5000: iconv-lite
# Processing 69/5000: resolve
# Processing 70/5000: inherits
# Processing 71/5000: qs
# Processing 72/5000: form-data
# Processing 73/5000: eslint-visitor-keys
# Processing 74/5000: json5
# Processing 75/5000: webidl-conversions
# Processing 76/5000: postcss
# Processing 77/5000: cross-spawn
# Processing 78/5000: make-dir
# Processing 79/5000: is-number
# Processing 80/5000: whatwg-url
# Processing 81/5000: pify
# Processing 82/5000: braces
# Processing 83/5000: fill-range
# Processing 84/5000: eslint-scope
# Processing 85/5000: micromatch
# Processing 86/5000: onetime
# Processing 87/5000: convert-source-map
# Processing 88/5000: tr46
# Processing 89/5000: @jest/types
# Processing 90/5000: agent-base
# Processing 91/5000: https-proxy-agent
# Processing 92/5000: npm-run-path
# Processing 93/5000: shebang-regex
# Processing 94/5000: shebang-command
# Processing 95/5000: buffer
# Processing 96/5000: globby
# Processing 97/5000: picocolors
# Processing 98/5000: mime
# Processing 99/5000: y18n
# Processing 100/5000: @babel/types
# Processing 101/5000: @babel/code-frame
# Processing 102/5000: @types/yargs
# Processing 103/5000: strip-bom
# Processing 104/5000: @jridgewell/trace-mapping
# Processing 105/5000: human-signals
# Processing 106/5000: to-regex-range
# Processing 107/5000: jsesc
# Processing 108/5000: doctrine
# Processing 109/5000: is-glob
# Processing 110/5000: typescript
# Processing 111/5000: ignore
# Processing 112/5000: pkg-dir
# Processing 113/5000: picomatch
# Processing 114/5000: regenerator-runtime
# Processing 115/5000: cosmiconfig
# Processing 116/5000: define-property
# Processing 117/5000: mime-db
# Processing 118/5000: parse-json
# Processing 119/5000: isexe
# Processing 120/5000: extend-shallow
# Processing 121/5000: jsonfile
# Processing 122/5000: graceful-fs
# Processing 123/5000: path-type
# Processing 124/5000: strip-json-comments
# Processing 125/5000: @babel/parser
# Processing 126/5000: normalize-path
# Processing 127/5000: jest-worker
# Processing 128/5000: @babel/generator
# Processing 129/5000: statuses
# Processing 130/5000: path-to-regexp
# Processing 131/5000: entities
# Processing 132/5000: async
# Processing 133/5000: balanced-match
# Processing 134/5000: minimist
# Processing 135/5000: sprintf-js
# Processing 136/5000: @babel/helper-validator-identifier
# Processing 137/5000: bytes
# Processing 138/5000: http-errors
# Processing 139/5000: jest-util
# Processing 140/5000: node-fetch
# Processing 141/5000: @babel/highlight
# Processing 142/5000: function-bind
# Processing 143/5000: @typescript-eslint/typescript-estree
# Processing 144/5000: mime-types
# Processing 145/5000: is-arrayish
# Processing 146/5000: @babel/runtime
# Processing 147/5000: source-map-support
# Processing 148/5000: axios
# Processing 149/5000: depd
# Processing 150/5000: @typescript-eslint/types
# Processing 151/5000: cookie
# Processing 152/5000: is-core-module
# Processing 153/5000: get-intrinsic
# Processing 154/5000: anymatch
# Processing 155/5000: @typescript-eslint/visitor-keys
# Processing 156/5000: lodash
# Processing 157/5000: @babel/core
# Processing 158/5000: chokidar
# Processing 159/5000: @babel/template
# Processing 160/5000: ansi-escapes
# Processing 161/5000: escalade
# Processing 162/5000: browserslist
# Processing 163/5000: once
# Processing 164/5000: write-file-atomic
# Processing 165/5000: object-inspect
# Processing 166/5000: yaml
# Processing 167/5000: @babel/traverse
# Processing 168/5000: yocto-queue
# Processing 169/5000: js-tokens
# Processing 170/5000: is-extglob
# Processing 171/5000: caniuse-lite
# Processing 172/5000: call-bind
# Processing 173/5000: strip-final-newline
# Processing 174/5000: electron-to-chromium
# Processing 175/5000: wrappy
# Processing 176/5000: ini
# Processing 177/5000: http-proxy-agent
# Processing 178/5000: fast-glob
# Processing 179/5000: fast-deep-equal
# Processing 180/5000: @typescript-eslint/scope-manager
# Processing 181/5000: hosted-git-info
# Processing 182/5000: ci-info
# Processing 183/5000: slice-ansi
# Processing 184/5000: @jridgewell/sourcemap-codec
# Processing 185/5000: concat-map
# Processing 186/5000: core-util-is
# Processing 187/5000: is-extendable
# Processing 188/5000: @jridgewell/gen-mapping
# Processing 189/5000: has-symbols
# Processing 190/5000: setprototypeof
# Processing 191/5000: ajv-keywords
# Processing 192/5000: @babel/helper-plugin-utils
# Processing 193/5000: readdirp
# Processing 194/5000: optionator
# Processing 195/5000: fs.realpath
# Processing 196/5000: p-try
# Processing 197/5000: loader-utils
# Processing 198/5000: callsites
# Processing 199/5000: esprima
# Processing 200/5000: istanbul-lib-instrument
# Processing 201/5000: get-caller-file
# Processing 202/5000: undici-types
#   Error: HTTP 404
# Processing 203/5000: type-check
# Processing 204/5000: prelude-ls
# Processing 205/5000: levn
# Processing 206/5000: node-releases
# Processing 207/5000: acorn-walk
# Processing 208/5000: has-property-descriptors
# Processing 209/5000: follow-redirects
# Processing 210/5000: binary-extensions
# Processing 211/5000: @jridgewell/resolve-uri
# Processing 212/5000: import-fresh
# Processing 213/5000: side-channel
# Processing 214/5000: util-deprecate
# Processing 215/5000: jest-get-type
# Processing 216/5000: @babel/helper-module-imports
# Processing 217/5000: ieee754
# Processing 218/5000: json-parse-even-better-errors
# Processing 219/5000: is-plain-obj
# Processing 220/5000: hasown
# Processing 221/5000: encodeurl
# Processing 222/5000: @babel/helper-module-transforms
# Processing 223/5000: safer-buffer
# Processing 224/5000: delayed-stream
# Processing 225/5000: rxjs
# Processing 226/5000: @babel/compat-data
# Processing 227/5000: @babel/helpers
# Processing 228/5000: path-parse
# Processing 229/5000: on-finished
# Processing 230/5000: combined-stream
# Processing 231/5000: @babel/helper-string-parser
#   Error: HTTP 404
# Processing 232/5000: @aws-sdk/types
# Processing 233/5000: asynckit
# Processing 234/5000: cli-cursor
# Processing 235/5000: is-plain-object
# Processing 236/5000: restore-cursor
# Processing 237/5000: isobject
# Processing 238/5000: array-union
# Processing 239/5000: diff
# Processing 240/5000: is-binary-path
# Processing 241/5000: @babel/helper-compilation-targets
# Processing 242/5000: @types/estree
# Processing 243/5000: require-directory
# Processing 244/5000: has-proto
#   Error: HTTP 404
# Processing 245/5000: @nodelib/fs.stat
# Processing 246/5000: espree
# Processing 247/5000: indent-string
# Processing 248/5000: parse5
# Processing 249/5000: object-assign
# Processing 250/5000: base64-js
# Processing 251/5000: eslint
# Processing 252/5000: tmp
# Processing 253/5000: normalize-package-data
# Processing 254/5000: uri-js
# Processing 255/5000: p-map
# Processing 256/5000: domutils
# Processing 257/5000: fast-json-stable-stringify
# Processing 258/5000: dotenv
# Processing 259/5000: esutils
# Processing 260/5000: @typescript-eslint/utils
# Processing 261/5000: fastq
# Processing 262/5000: @babel/helper-validator-option
# Processing 263/5000: lines-and-columns
# Processing 264/5000: imurmurhash
# Processing 265/5000: pump
# Processing 266/5000: @babel/helper-simple-access
# Processing 267/5000: dom-serializer
# Processing 268/5000: ipaddr.js
# Processing 269/5000: is-descriptor
# Processing 270/5000: postcss-value-parser
# Processing 271/5000: prettier
# Processing 272/5000: supports-preserve-symlinks-flag
# Processing 273/5000: to-fast-properties
# Processing 274/5000: is-wsl
# Processing 275/5000: nanoid
# Processing 276/5000: gopd
#   Error: HTTP 404
# Processing 277/5000: jest-message-util
# Processing 278/5000: domhandler
# Processing 279/5000: update-browserslist-db
#   Error: HTTP 404
# Processing 280/5000: @jridgewell/set-array
# Processing 281/5000: define-data-property
#   Error: HTTP 404
# Processing 282/5000: chownr
# Processing 283/5000: is-path-inside
# Processing 284/5000: flat-cache
# Processing 285/5000: diff-sequences
# Processing 286/5000: define-properties
# Processing 287/5000: @nodelib/fs.walk
# Processing 288/5000: @nodelib/fs.scandir
# Processing 289/5000: tough-cookie
# Processing 290/5000: flatted
# Processing 291/5000: es-abstract
# Processing 292/5000: is-callable
# Processing 293/5000: file-entry-cache
# Processing 294/5000: buffer-from
# Processing 295/5000: open
# Processing 296/5000: run-parallel
# Processing 297/5000: fast-levenshtein
# Processing 298/5000: reusify
# Processing 299/5000: set-function-length
#   Error: HTTP 404
# Processing 300/5000: has-tostringtag
# Processing 301/5000: parent-module
# Processing 302/5000: jest-diff
# Processing 303/5000: queue-microtask
# Processing 304/5000: object.assign
# Processing 305/5000: events
# Processing 306/5000: merge2
# Processing 307/5000: serialize-javascript
# Processing 308/5000: raw-body
# Processing 309/5000: dir-glob
# Processing 310/5000: postcss-selector-parser
# Processing 311/5000: finalhandler
# Processing 312/5000: @smithy/types
#   Error: HTTP 404
# Processing 313/5000: esbuild
# Processing 314/5000: find-cache-dir
# Processing 315/5000: error-ex
# Processing 316/5000: merge-stream
# Processing 317/5000: which-typed-array
# Processing 318/5000: log-symbols
# Processing 319/5000: deep-is
# Processing 320/5000: deepmerge
# Processing 321/5000: object-keys
# Processing 322/5000: esrecurse
# Processing 323/5000: body-parser
# Processing 324/5000: domelementtype
# Processing 325/5000: bn.js
# Processing 326/5000: @typescript-eslint/parser
# Processing 327/5000: figures
# Processing 328/5000: esquery
# Processing 329/5000: read-pkg
# Processing 330/5000: @smithy/util-utf8
#   Error: HTTP 404
# Processing 331/5000: jest-regex-util
# Processing 332/5000: process-nextick-args
# Processing 333/5000: @eslint/eslintrc
# Processing 334/5000: retry
# Processing 335/5000: negotiator
# Processing 336/5000: send
# Processing 337/5000: proxy-from-env
# Processing 338/5000: natural-compare
# Processing 339/5000: regexp.prototype.flags
# Processing 340/5000: jest-matcher-utils
# Processing 341/5000: acorn-jsx
# Processing 342/5000: is-typed-array
# Processing 343/5000: sax
# Processing 344/5000: magic-string
# Processing 345/5000: @types/json-schema
# Processing 346/5000: fs-minipass
# Processing 347/5000: @ampproject/remapping
# Processing 348/5000: eventemitter3
# Processing 349/5000: bl
# Processing 350/5000: available-typed-arrays
# Processing 351/5000: array-flatten
# Processing 352/5000: string.prototype.trimend
# Processing 353/5000: string.prototype.trimstart
# Processing 354/5000: end-of-stream
# Processing 355/5000: text-table
# Processing 356/5000: tapable
# Processing 357/5000: es-errors
#   Error: HTTP 404
# Processing 358/5000: is-regex
# Processing 359/5000: serve-static
# Processing 360/5000: internal-slot
# Processing 361/5000: core-js
# Processing 362/5000: lodash.merge
# Processing 363/5000: jsbn
# Processing 364/5000: terser
# Processing 365/5000: foreground-child
# Processing 366/5000: es-define-property
#   Error: HTTP 404
# Processing 367/5000: enhanced-resolve
# Processing 368/5000: toidentifier
# Processing 369/5000: keyv
# Processing 370/5000: tsconfig-paths
# Processing 371/5000: clone
# Processing 372/5000: decamelize
# Processing 373/5000: @babel/helper-annotate-as-pure
# Processing 374/5000: json-stable-stringify-without-jsonify
# Processing 375/5000: @smithy/util-buffer-from
#   Error: HTTP 404
# Processing 376/5000: gensync
# Processing 377/5000: express
# Processing 378/5000: arg
# Processing 379/5000: istanbul-lib-coverage
# Processing 380/5000: css-select
# Processing 381/5000: content-disposition
# Processing 382/5000: destroy
# Processing 383/5000: source-map-js
# Processing 384/5000: nopt
# Processing 385/5000: jackspeak
# Processing 386/5000: escape-html
# Processing 387/5000: accepts
# Processing 388/5000: json-buffer
# Processing 389/5000: @typescript-eslint/eslint-plugin
# Processing 390/5000: is-date-object
# Processing 391/5000: colorette
# Processing 392/5000: range-parser
# Processing 393/5000: webpack-sources
# Processing 394/5000: jest-haste-map
# Processing 395/5000: is-docker
# Processing 396/5000: is-shared-array-buffer
# Processing 397/5000: is-negative-zero
# Processing 398/5000: is-symbol
# Processing 399/5000: content-type
# Processing 400/5000: for-each
# Processing 401/5000: @sinclair/typebox
# Processing 402/5000: escodegen
# Processing 403/5000: @babel/plugin-syntax-jsx
# Processing 404/5000: cssom
# Processing 405/5000: htmlparser2
# Processing 406/5000: @jest/schemas
# Processing 407/5000: is-buffer
# Processing 408/5000: ee-first
# Processing 409/5000: unpipe
# Processing 410/5000: @sinonjs/commons
# Processing 411/5000: expect
# Processing 412/5000: is-string
# Processing 413/5000: vary
# Processing 414/5000: is-unicode-supported
# Processing 415/5000: aria-query
# Processing 416/5000: mimic-response
# Processing 417/5000: @esbuild/linux-x64
#   Error: HTTP 404
# Processing 418/5000: @smithy/is-array-buffer
#   Error: HTTP 404
# Processing 419/5000: jest-mock
# Processing 420/5000: css-tree
# Processing 421/5000: mdn-data
# Processing 422/5000: has-bigints
# Processing 423/5000: fresh
# Processing 424/5000: methods
# Processing 425/5000: parseurl
# Processing 426/5000: cookie-signature
# Processing 427/5000: merge-descriptors
# Processing 428/5000: csstype
# Processing 429/5000: util
# Processing 430/5000: etag
# Processing 431/5000: require-from-string
# Processing 432/5000: path-scurry
#   Error: HTTP 404
# Processing 433/5000: mute-stream
# Processing 434/5000: @sinonjs/fake-timers
# Processing 435/5000: get-symbol-description
# Processing 436/5000: ansi-colors
# Processing 437/5000: @typescript-eslint/type-utils
# Processing 438/5000: is-number-object
# Processing 439/5000: estree-walker
# Processing 440/5000: media-typer
# Processing 441/5000: type-detect
# Processing 442/5000: es-to-primitive
# Processing 443/5000: is-boolean-object
# Processing 444/5000: utils-merge
# Processing 445/5000: inquirer
# Processing 446/5000: kleur
# Processing 447/5000: xtend
# Processing 448/5000: is-bigint
# Processing 449/5000: functions-have-names
# Processing 450/5000: clean-stack
# Processing 451/5000: function.prototype.name
# Processing 452/5000: unbox-primitive
# Processing 453/5000: which-boxed-primitive
# Processing 454/5000: type-is
# Processing 455/5000: @eslint-community/regexpp
#   Error: HTTP 404
# Processing 456/5000: @babel/helper-replace-supers
# Processing 457/5000: through2
# Processing 458/5000: through
# Processing 459/5000: istanbul-reports
# Processing 460/5000: is-array-buffer
# Processing 461/5000: @eslint/js
#   Error: HTTP 404
# Processing 462/5000: proxy-addr
# Processing 463/5000: @babel/helper-create-class-features-plugin
# Processing 464/5000: @babel/helper-member-expression-to-functions
# Processing 465/5000: forwarded
# Processing 466/5000: psl
# Processing 467/5000: word-wrap
# Processing 468/5000: scheduler
# Processing 469/5000: tar-stream
# Processing 470/5000: @babel/helper-define-polyfill-provider
# Processing 471/5000: ora
# Processing 472/5000: tar
# Processing 473/5000: @tootallnate/once
# Processing 474/5000: @babel/plugin-syntax-object-rest-spread
# Processing 475/5000: pirates
# Processing 476/5000: css-what
# Processing 477/5000: @babel/plugin-syntax-class-properties
# Processing 478/5000: istanbul-lib-report
# Processing 479/5000: lilconfig
# Processing 480/5000: is-weakref
# Processing 481/5000: test-exclude
# Processing 482/5000: safe-regex-test
#   Error: HTTP 404
# Processing 483/5000: ssri
# Processing 484/5000: @babel/plugin-syntax-top-level-await
# Processing 485/5000: @babel/plugin-syntax-optional-catch-binding
# Processing 486/5000: @babel/plugin-syntax-async-generators
# Processing 487/5000: array-buffer-byte-length
#   Error: HTTP 404
# Processing 488/5000: @babel/plugin-syntax-typescript
# Processing 489/5000: aggregate-error
# Processing 490/5000: @babel/plugin-syntax-json-strings
# Processing 491/5000: string.prototype.trim
# Processing 492/5000: globalthis
# Processing 493/5000: string-length
# Processing 494/5000: @babel/plugin-syntax-numeric-separator
# Processing 495/5000: cacache
# Processing 496/5000: @babel/plugin-syntax-optional-chaining
# Processing 497/5000: extend
# Processing 498/5000: @babel/plugin-syntax-nullish-coalescing-operator
# Processing 499/5000: normalize-url
# Processing 500/5000: nth-check
# Processing 501/5000: object.values
# Processing 502/5000: jest-resolve
# Processing 503/5000: @types/react
# Processing 504/5000: @babel/plugin-syntax-logical-assignment-operators
# Processing 505/5000: istanbul-lib-source-maps
# Processing 506/5000: typed-array-length
# Processing 507/5000: es-set-tostringtag
#   Error: HTTP 404
# Processing 508/5000: terser-webpack-plugin
# Processing 509/5000: @babel/helper-optimise-call-expression
# Processing 510/5000: @babel/helper-split-export-declaration
# Processing 511/5000: requires-port
# Processing 512/5000: spdx-license-ids
# Processing 513/5000: import-local
# Processing 514/5000: html-escaper
# Processing 515/5000: @babel/plugin-transform-modules-commonjs
# Processing 516/5000: eastasianwidth
# Processing 517/5000: xmlbuilder
# Processing 518/5000: loose-envify
# Processing 519/5000: cli-width
# Processing 520/5000: bluebird
# Processing 521/5000: jest-validate
# Processing 522/5000: pako
# Processing 523/5000: spdx-expression-parse
# Processing 524/5000: dedent
# Processing 525/5000: array-includes
# Processing 526/5000: neo-async
# Processing 527/5000: strip-indent
# Processing 528/5000: jest-watcher
# Processing 529/5000: @eslint-community/eslint-utils
#   Error: HTTP 404
# Processing 530/5000: resolve-cwd
# Processing 531/5000: webpack
# Processing 532/5000: watchpack
# Processing 533/5000: babel-jest
# Processing 534/5000: @types/babel__traverse
# Processing 535/5000: @humanwhocodes/module-importer
#   Error: HTTP 404
# Processing 536/5000: @types/istanbul-lib-coverage
# Processing 537/5000: @types/babel__core
# Processing 538/5000: cssesc
# Processing 539/5000: babel-plugin-polyfill-corejs3
# Processing 540/5000: leven
# Processing 541/5000: @babel/preset-env
# Processing 542/5000: react
# Processing 543/5000: @babel/plugin-syntax-import-meta
# Processing 544/5000: randombytes
# Processing 545/5000: cjs-module-lexer
# Processing 546/5000: stack-utils
# Processing 547/5000: spdx-exceptions
# Processing 548/5000: abbrev
# Processing 549/5000: @babel/plugin-transform-classes
# Processing 550/5000: @babel/helper-skip-transparent-expression-wrappers
# Processing 551/5000: jest-snapshot
# Processing 552/5000: set-function-name
# Processing 553/5000: babel-preset-jest
# Processing 554/5000: safe-array-concat
#   Error: HTTP 404
# Processing 555/5000: babel-plugin-jest-hoist
# Processing 556/5000: cli-spinners
# Processing 557/5000: prop-types
# Processing 558/5000: core-js-compat
# Processing 559/5000: @types/yargs-parser
# Processing 560/5000: arrify
# Processing 561/5000: is-accessor-descriptor
# Processing 562/5000: is-data-descriptor
# Processing 563/5000: emittery
# Processing 564/5000: is-arguments
# Processing 565/5000: regjsparser
# Processing 566/5000: @babel/helper-function-name
# Processing 567/5000: @types/qs
# Processing 568/5000: @babel/plugin-transform-destructuring
# Processing 569/5000: @babel/plugin-transform-parameters
# Processing 570/5000: jest-environment-node
# Processing 571/5000: @babel/plugin-transform-block-scoping
# Processing 572/5000: jest-docblock
# Processing 573/5000: @babel/helper-create-regexp-features-plugin
# Processing 574/5000: prompts
# Processing 575/5000: @types/istanbul-reports
# Processing 576/5000: set-blocking
# Processing 577/5000: @jest/source-map
# Processing 578/5000: spdx-correct
# Processing 579/5000: @types/stack-utils
# Processing 580/5000: @types/babel__generator
# Processing 581/5000: jws
# Processing 582/5000: is-typedarray
# Processing 583/5000: jest-config
# Processing 584/5000: jwa
# Processing 585/5000: arraybuffer.prototype.slice
#   Error: HTTP 404
# Processing 586/5000: array.prototype.flat
# Processing 587/5000: minizlib
# Processing 588/5000: @types/express
# Processing 589/5000: typed-array-byte-offset
#   Error: HTTP 404
# Processing 590/5000: typed-array-buffer
#   Error: HTTP 404
# Processing 591/5000: @types/babel__template
# Processing 592/5000: typed-array-byte-length
#   Error: HTTP 404
# Processing 593/5000: @babel/plugin-transform-literals
# Processing 594/5000: @babel/plugin-transform-function-name
# Processing 595/5000: rollup
# Processing 596/5000: whatwg-mimetype
# Processing 597/5000: jest-runtime
# Processing 598/5000: @types/istanbul-lib-report
# Processing 599/5000: @babel/plugin-transform-arrow-functions
# Processing 600/5000: @babel/plugin-transform-spread
# Processing 601/5000: @babel/plugin-transform-for-of
# Processing 602/5000: @babel/plugin-transform-computed-properties
# Processing 603/5000: @babel/plugin-transform-shorthand-properties
# Processing 604/5000: process
# Processing 605/5000: @babel/plugin-transform-template-literals
# Processing 606/5000: @isaacs/cliui
#   Error: HTTP 404
# Processing 607/5000: char-regex
# Processing 608/5000: v8-to-istanbul
# Processing 609/5000: @jest/transform
# Processing 610/5000: jest
# Processing 611/5000: graphemer
# Processing 612/5000: jest-each
# Processing 613/5000: @types/express-serve-static-core
# Processing 614/5000: @pkgjs/parseargs
# Processing 615/5000: @smithy/property-provider
#   Error: HTTP 404
# Processing 616/5000: long
# Processing 617/5000: babel-plugin-istanbul
# Processing 618/5000: sisteransi
# Processing 619/5000: detect-newline
# Processing 620/5000: jest-runner
# Processing 621/5000: @babel/plugin-transform-object-super
# Processing 622/5000: @babel/plugin-transform-block-scoped-functions
# Processing 623/5000: jest-leak-detector
# Processing 624/5000: regexpu-core
# Processing 625/5000: get-package-type
# Processing 626/5000: validate-npm-package-license
# Processing 627/5000: @jest/test-sequencer
# Processing 628/5000: jsdom
# Processing 629/5000: @babel/plugin-transform-property-literals
# Processing 630/5000: @babel/plugin-transform-member-expression-literals
# Processing 631/5000: @babel/plugin-transform-async-to-generator
# Processing 632/5000: babel-plugin-polyfill-regenerator
# Processing 633/5000: @babel/helper-remap-async-to-generator
# Processing 634/5000: eslint-plugin-import
# Processing 635/5000: @webassemblyjs/helper-wasm-bytecode
# Processing 636/5000: socks-proxy-agent
# Processing 637/5000: fsevents
# Processing 638/5000: react-dom
# Processing 639/5000: @colors/colors
# Processing 640/5000: jest-cli
# Processing 641/5000: @types/connect
# Processing 642/5000: ts-node
# Processing 643/5000: jest-changed-files
# Processing 644/5000: possible-typed-array-names
#   Error: HTTP 404
# Processing 645/5000: @babel/helper-wrap-function
# Processing 646/5000: jest-resolve-dependencies
# Processing 647/5000: @jest/globals
# Processing 648/5000: @webassemblyjs/wast-printer
# Processing 649/5000: map-obj
# Processing 650/5000: @jest/core
# Processing 651/5000: es-shim-unscopables
# Processing 652/5000: object.fromentries
# Processing 653/5000: define-lazy-prop
# Processing 654/5000: eslint-module-utils
# Processing 655/5000: whatwg-encoding
# Processing 656/5000: @jest/test-result
# Processing 657/5000: @babel/plugin-transform-modules-systemjs
# Processing 658/5000: url-parse
# Processing 659/5000: @types/semver
# Processing 660/5000: @webassemblyjs/wasm-gen
# Processing 661/5000: @babel/helper-environment-visitor
# Processing 662/5000: @babel/plugin-transform-regenerator
# Processing 663/5000: @webassemblyjs/wasm-edit
# Processing 664/5000: co
# Processing 665/5000: @webassemblyjs/wasm-opt
# Processing 666/5000: @webassemblyjs/helper-wasm-section
# Processing 667/5000: is-generator-function
# Processing 668/5000: @webassemblyjs/helper-buffer
# Processing 669/5000: @babel/plugin-transform-unicode-regex
# Processing 670/5000: array.prototype.flatmap
# Processing 671/5000: ajv-formats
# Processing 672/5000: @babel/plugin-transform-sticky-regex
# Processing 673/5000: @webassemblyjs/helper-api-error
# Processing 674/5000: regenerator-transform
# Processing 675/5000: extsprintf
# Processing 676/5000: @babel/plugin-transform-dotall-regex
# Processing 677/5000: make-error
# Processing 678/5000: @babel/plugin-transform-exponentiation-operator
# Processing 679/5000: babel-plugin-polyfill-corejs2
# Processing 680/5000: @babel/plugin-transform-typeof-symbol
# Processing 681/5000: querystringify
# Processing 682/5000: @types/lodash
# Processing 683/5000: glob-to-regexp
# Processing 684/5000: @babel/plugin-transform-modules-amd
# Processing 685/5000: @types/serve-static
# Processing 686/5000: json-stringify-safe
# Processing 687/5000: @jest/console
# Processing 688/5000: xml-name-validator
# Processing 689/5000: node-int64
# Processing 690/5000: @babel/plugin-transform-modules-umd
# Processing 691/5000: @types/jest
# Processing 692/5000: @babel/plugin-transform-duplicate-keys
# Processing 693/5000: fb-watchman
# Processing 694/5000: @babel/helper-builder-binary-assignment-operator-visitor
# Processing 695/5000: regenerate-unicode-properties
# Processing 696/5000: @babel/plugin-transform-new-target
# Processing 697/5000: eslint-import-resolver-node
# Processing 698/5000: @webassemblyjs/leb128
# Processing 699/5000: @webassemblyjs/ieee754
# Processing 700/5000: @webassemblyjs/utf8
# Processing 701/5000: @smithy/protocol-http
#   Error: HTTP 404
# Processing 702/5000: @babel/plugin-transform-named-capturing-groups-regex
# Processing 703/5000: @babel/plugin-transform-reserved-words
# Processing 704/5000: lowercase-keys
# Processing 705/5000: @types/body-parser
# Processing 706/5000: is-obj
# Processing 707/5000: eslint-config-prettier
# Processing 708/5000: fast-xml-parser
# Processing 709/5000: bser
# Processing 710/5000: boolbase
# Processing 711/5000: unicode-match-property-value-ecmascript
# Processing 712/5000: run-async
# Processing 713/5000: html-encoding-sniffer
# Processing 714/5000: @babel/plugin-transform-unicode-escapes
# Processing 715/5000: loader-runner
# Processing 716/5000: resolve.exports
# Processing 717/5000: clsx
# Processing 718/5000: quick-lru
# Processing 719/5000: deep-equal
# Processing 720/5000: decompress-response
# Processing 721/5000: @jest/fake-timers
# Processing 722/5000: data-urls
# Processing 723/5000: date-fns
# Processing 724/5000: @types/range-parser
# Processing 725/5000: makeerror
# Processing 726/5000: walker
# Processing 727/5000: @webassemblyjs/floating-point-hex-parser
# Processing 728/5000: @bcoe/v8-coverage
# Processing 729/5000: es-module-lexer
# Processing 730/5000: has-values
# Processing 731/5000: @babel/helper-hoist-variables
# Processing 732/5000: dayjs
# Processing 733/5000: has-value
# Processing 734/5000: @jest/environment
# Processing 735/5000: @babel/preset-modules
# Processing 736/5000: tmpl
# Processing 737/5000: exit
# Processing 738/5000: is-interactive
# Processing 739/5000: http-cache-semantics
# Processing 740/5000: lodash.debounce
# Processing 741/5000: ast-types
# Processing 742/5000: cssstyle
# Processing 743/5000: unicode-canonical-property-names-ecmascript
# Processing 744/5000: moment
# Processing 745/5000: astral-regex
# Processing 746/5000: file-type
# Processing 747/5000: object.entries
# Processing 748/5000: @babel/plugin-bugfix-v8-spread-parameters-in-optional-chaining
# Processing 749/5000: defaults
# Processing 750/5000: @types/graceful-fs
# Processing 751/5000: buffer-crc32
# Processing 752/5000: @babel/plugin-syntax-private-property-in-object
# Processing 753/5000: @types/prop-types
# Processing 754/5000: regenerate
# Processing 755/5000: @babel/plugin-syntax-import-assertions
# Processing 756/5000: @aws-sdk/credential-provider-node
# Processing 757/5000: @jridgewell/source-map
# Processing 758/5000: @babel/plugin-syntax-class-static-block
# Processing 759/5000: wcwidth
# Processing 760/5000: unicode-property-aliases-ecmascript
# Processing 761/5000: he
# Processing 762/5000: redent
# Processing 763/5000: @aws-sdk/middleware-user-agent
# Processing 764/5000: @istanbuljs/schema
# Processing 765/5000: @aws-sdk/credential-provider-ini
# Processing 766/5000: shell-quote
# Processing 767/5000: chardet
# Processing 768/5000: xml2js
# Processing 769/5000: @babel/plugin-bugfix-safari-id-destructuring-collision-in-function-expression
# Processing 770/5000: saxes
# Processing 771/5000: babel-preset-current-node-syntax
# Processing 772/5000: lodash.isplainobject
# Processing 773/5000: jest-circus
# Processing 774/5000: concat-stream
# Processing 775/5000: w3c-xmlserializer
# Processing 776/5000: socks
# Processing 777/5000: on-headers
# Processing 778/5000: unicode-match-property-ecmascript
# Processing 779/5000: jest-pnp-resolver
# Processing 780/5000: got
# Processing 781/5000: tunnel-agent
# Processing 782/5000: split2
# Processing 783/5000: external-editor
# Processing 784/5000: unique-slug
# Processing 785/5000: unique-filename
# Processing 786/5000: commondir
# Processing 787/5000: autoprefixer
# Processing 788/5000: cli-truncate
# Processing 789/5000: performance-now
# Processing 790/5000: @babel/plugin-syntax-dynamic-import
# Processing 791/5000: @jest/expect-utils
# Processing 792/5000: meow
# Processing 793/5000: eslint-utils
# Processing 794/5000: @aws-sdk/util-user-agent-node
# Processing 795/5000: is-generator-fn
# Processing 796/5000: has
# Processing 797/5000: require-main-filename
# Processing 798/5000: @aws-sdk/middleware-host-header
# Processing 799/5000: yn
# Processing 800/5000: color
# Processing 801/5000: tsutils
# Processing 802/5000: @babel/plugin-syntax-bigint
# Processing 803/5000: collect-v8-coverage
# Processing 804/5000: big.js
# Processing 805/5000: @aws-sdk/client-sts
# Processing 806/5000: chrome-trace-event
# Processing 807/5000: object-hash
# Processing 808/5000: @aws-sdk/middleware-logger
# Processing 809/5000: @aws-sdk/util-user-agent-browser
# Processing 810/5000: @ungap/structured-clone
# Processing 811/5000: lodash.memoize
# Processing 812/5000: node-forge
# Processing 813/5000: @babel/plugin-syntax-import-attributes
#   Error: HTTP 404
# Processing 814/5000: @aws-sdk/credential-provider-sso
# Processing 815/5000: @aws-sdk/client-sso
# Processing 816/5000: @aws-sdk/credential-provider-process
# Processing 817/5000: eslint-plugin-react
# Processing 818/5000: @types/unist
# Processing 819/5000: @types/parse-json
# Processing 820/5000: @aws-sdk/credential-provider-env
# Processing 821/5000: uglify-js
# Processing 822/5000: interpret
# Processing 823/5000: tweetnacl
# Processing 824/5000: @webassemblyjs/ast
# Processing 825/5000: which-module
# Processing 826/5000: @babel/plugin-syntax-export-namespace-from
# Processing 827/5000: json-schema
# Processing 828/5000: assert-plus
# Processing 829/5000: emojis-list
# Processing 830/5000: component-emitter
# Processing 831/5000: object-is
# Processing 832/5000: aproba
# Processing 833/5000: url
# Processing 834/5000: @jest/reporters
# Processing 835/5000: compressible
# Processing 836/5000: immutable
# Processing 837/5000: detect-libc
# Processing 838/5000: smart-buffer
# Processing 839/5000: dot-prop
# Processing 840/5000: create-require
# Processing 841/5000: rfdc
# Processing 842/5000: nwsapi
# Processing 843/5000: @xtuc/long
# Processing 844/5000: webpack-dev-middleware
# Processing 845/5000: css-loader
# Processing 846/5000: is-windows
# Processing 847/5000: @xtuc/ieee754
# Processing 848/5000: protobufjs
# Processing 849/5000: jsonc-parser
# Processing 850/5000: @aws-sdk/util-endpoints
#   Error: HTTP 404
# Processing 851/5000: @aws-crypto/util
# Processing 852/5000: p-cancelable
# Processing 853/5000: node-addon-api
# Processing 854/5000: event-target-shim
# Processing 855/5000: @webassemblyjs/wasm-parser
# Processing 856/5000: @istanbuljs/load-nyc-config
# Processing 857/5000: make-fetch-happen
# Processing 858/5000: http-signature
# Processing 859/5000: @types/eslint
# Processing 860/5000: @aws-crypto/sha256-js
# Processing 861/5000: @aws-sdk/credential-provider-web-identity
# Processing 862/5000: is-ci
# Processing 863/5000: @sindresorhus/is
# Processing 864/5000: wordwrap
# Processing 865/5000: @tsconfig/node16
# Processing 866/5000: @aws-sdk/middleware-recursion-detection
# Processing 867/5000: jsx-ast-utils
# Processing 868/5000: asap
# Processing 869/5000: aws4
# Processing 870/5000: abort-controller
# Processing 871/5000: @tsconfig/node10
# Processing 872/5000: minimalistic-assert
# Processing 873/5000: es-object-atoms
#   Error: HTTP 404
# Processing 874/5000: progress
# Processing 875/5000: load-json-file
# Processing 876/5000: @npmcli/fs
# Processing 877/5000: data-view-byte-length
#   Error: HTTP 404
# Processing 878/5000: @smithy/util-retry
#   Error: HTTP 404
# Processing 879/5000: data-view-buffer
#   Error: HTTP 404
# Processing 880/5000: data-view-byte-offset
#   Error: HTTP 404
# Processing 881/5000: is-data-view
#   Error: HTTP 404
# Processing 882/5000: @emotion/memoize
# Processing 883/5000: @tsconfig/node14
# Processing 884/5000: asn1
# Processing 885/5000: decimal.js
# Processing 886/5000: log-update
# Processing 887/5000: is-set
# Processing 888/5000: is-map
# Processing 889/5000: compression
# Processing 890/5000: string.prototype.matchall
# Processing 891/5000: @babel/plugin-transform-optional-chaining
#   Error: HTTP 404
# Processing 892/5000: verror
# Processing 893/5000: @types/send
# Processing 894/5000: @cspotcode/source-map-support
# Processing 895/5000: @smithy/shared-ini-file-loader
#   Error: HTTP 404
# Processing 896/5000: tar-fs
# Processing 897/5000: clone-deep
# Processing 898/5000: shallow-clone
# Processing 899/5000: xmlchars
# Processing 900/5000: postcss-modules-local-by-default
# Processing 901/5000: env-paths
# Processing 902/5000: html-entities
# Processing 903/5000: dom-accessibility-api
# Processing 904/5000: symbol-tree
# Processing 905/5000: acorn-globals
# Processing 906/5000: babel-loader
# Processing 907/5000: ts-api-utils
#   Error: HTTP 404
# Processing 908/5000: postcss-modules-scope
# Processing 909/5000: color-string
# Processing 910/5000: min-indent
# Processing 911/5000: @tsconfig/node12
# Processing 912/5000: sshpk
# Processing 913/5000: @aws-sdk/token-providers
#   Error: HTTP 404
# Processing 914/5000: postcss-modules-extract-imports
# Processing 915/5000: @types/normalize-package-data
# Processing 916/5000: @smithy/node-config-provider
#   Error: HTTP 404
# Processing 917/5000: @webassemblyjs/helper-numbers
# Processing 918/5000: jsprim
# Processing 919/5000: @babel/plugin-transform-async-generator-functions
#   Error: HTTP 404
# Processing 920/5000: @types/http-errors
# Processing 921/5000: @babel/plugin-transform-private-methods
#   Error: HTTP 404
# Processing 922/5000: svgo
# Processing 923/5000: nan
#   Error: quote_from_bytes() expected bytes
# Processing 924/5000: bcrypt-pbkdf
# Processing 925/5000: v8-compile-cache-lib
# Processing 926/5000: axe-core
# Processing 927/5000: @types/uuid
# Processing 928/5000: @smithy/node-http-handler
#   Error: HTTP 404
# Processing 929/5000: @babel/plugin-transform-typescript
# Processing 930/5000: @babel/plugin-transform-class-properties
#   Error: HTTP 404
# Processing 931/5000: caseless
# Processing 932/5000: minipass-fetch
# Processing 933/5000: @opentelemetry/semantic-conventions
# Processing 934/5000: @smithy/util-middleware
#   Error: HTTP 404
# Processing 935/5000: ejs
# Processing 936/5000: @graphql-tools/utils
# Processing 937/5000: @smithy/abort-controller
#   Error: HTTP 404
# Processing 938/5000: cacheable-request
# Processing 939/5000: eslint-plugin-react-hooks
# Processing 940/5000: is-weakset
# Processing 941/5000: which-collection
# Processing 942/5000: is-weakmap
# Processing 943/5000: typedarray
# Processing 944/5000: @types/react-dom
# Processing 945/5000: hoist-non-react-statics
# Processing 946/5000: @babel/plugin-transform-nullish-coalescing-operator
#   Error: HTTP 404
# Processing 947/5000: crypto-random-string
# Processing 948/5000: axobject-query
# Processing 949/5000: postcss-modules-values
# Processing 950/5000: setimmediate
# Processing 951/5000: duplexify
# Processing 952/5000: @babel/regjsgen
#   Error: HTTP 404
# Processing 953/5000: @babel/plugin-transform-private-property-in-object
#   Error: HTTP 404
# Processing 954/5000: listr2
# Processing 955/5000: @smithy/querystring-builder
#   Error: HTTP 404
# Processing 956/5000: is-potential-custom-element-name
# Processing 957/5000: @babel/plugin-transform-unicode-sets-regex
#   Error: HTTP 404
# Processing 958/5000: unique-string
# Processing 959/5000: icss-utils
# Processing 960/5000: @babel/plugin-transform-object-rest-spread
#   Error: HTTP 404
# Processing 961/5000: @babel/plugin-transform-export-namespace-from
#   Error: HTTP 404
# Processing 962/5000: aws-sign2
# Processing 963/5000: dashdash
# Processing 964/5000: @smithy/smithy-client
#   Error: HTTP 404
# Processing 965/5000: @babel/plugin-transform-react-jsx
# Processing 966/5000: ecc-jsbn
# Processing 967/5000: @types/ws
# Processing 968/5000: getpass
# Processing 969/5000: simple-swizzle
# Processing 970/5000: @babel/plugin-transform-numeric-separator
#   Error: HTTP 404
# Processing 971/5000: @babel/plugin-transform-logical-assignment-operators
#   Error: HTTP 404
# Processing 972/5000: @babel/plugin-transform-class-static-block
#   Error: HTTP 404
# Processing 973/5000: ecdsa-sig-formatter
# Processing 974/5000: @babel/preset-typescript
# Processing 975/5000: @babel/plugin-transform-optional-catch-binding
#   Error: HTTP 404
# Processing 976/5000: decode-uri-component
# Processing 977/5000: @babel/plugin-transform-json-strings
#   Error: HTTP 404
# Processing 978/5000: @babel/plugin-transform-dynamic-import
#   Error: HTTP 404
# Processing 979/5000: @testing-library/dom
# Processing 980/5000: buffer-equal-constant-time
# Processing 981/5000: @babel/plugin-transform-unicode-property-regex
#   Error: HTTP 404
# Processing 982/5000: global-prefix
# Processing 983/5000: rechoir
# Processing 984/5000: enquirer
# Processing 985/5000: normalize-range
# Processing 986/5000: isstream
# Processing 987/5000: @smithy/util-uri-escape
#   Error: HTTP 404
# Processing 988/5000: responselike
# Processing 989/5000: @smithy/fetch-http-handler
#   Error: HTTP 404
# Processing 990/5000: @smithy/util-hex-encoding
#   Error: HTTP 404
# Processing 991/5000: at-least-node
# Processing 992/5000: supports-hyperlinks
# Processing 993/5000: deep-extend
# Processing 994/5000: @babel/plugin-transform-runtime
# Processing 995/5000: @jest/expect
# Processing 996/5000: @smithy/util-stream
#   Error: HTTP 404
# Processing 997/5000: cross-fetch
# Processing 998/5000: forever-agent
# Processing 999/5000: yauzl
# Processing 1000/5000: jiti
# Processing 1001/5000: @babel/plugin-transform-react-display-name
# Processing 1002/5000: colors
# Processing 1003/5000: dotenv-expand
# Processing 1004/5000: jsonwebtoken
# Processing 1005/5000: global-modules
# Processing 1006/5000: repeat-string
# Processing 1007/5000: package-json-from-dist
#   Error: HTTP 404
# Processing 1008/5000: @smithy/url-parser
#   Error: HTTP 404
# Processing 1009/5000: fast-diff
# Processing 1010/5000: minipass-collect
# Processing 1011/5000: @octokit/types
# Processing 1012/5000: memfs
# Processing 1013/5000: data-uri-to-buffer
# Processing 1014/5000: lodash.once
# Processing 1015/5000: @rollup/pluginutils
# Processing 1016/5000: @smithy/querystring-parser
#   Error: HTTP 404
# Processing 1017/5000: @smithy/middleware-endpoint
#   Error: HTTP 404
# Processing 1018/5000: pnpm
# Processing 1019/5000: @smithy/middleware-stack
#   Error: HTTP 404
# Processing 1020/5000: @aws-sdk/core
#   Error: HTTP 404
# Processing 1021/5000: @emotion/unitless
# Processing 1022/5000: babel-plugin-macros
# Processing 1023/5000: faye-websocket
# Processing 1024/5000: @smithy/middleware-serde
#   Error: HTTP 404
# Processing 1025/5000: typedarray-to-buffer
# Processing 1026/5000: @szmarczak/http-timer
# Processing 1027/5000: array.prototype.findlastindex
# Processing 1028/5000: any-promise
# Processing 1029/5000: object.groupby
#   Error: HTTP 404
# Processing 1030/5000: @aws-sdk/client-sso-oidc
# Processing 1031/5000: get-stdin
# Processing 1032/5000: @smithy/service-error-classification
#   Error: HTTP 404
# Processing 1033/5000: @aws-crypto/supports-web-crypto
# Processing 1034/5000: vite
# Processing 1035/5000: jest-environment-jsdom
# Processing 1036/5000: flat
# Processing 1037/5000: dequal
# Processing 1038/5000: @aws-crypto/sha256-browser
# Processing 1039/5000: @smithy/signature-v4
#   Error: HTTP 404
# Processing 1040/5000: @aws-sdk/region-config-resolver
#   Error: HTTP 404
# Processing 1041/5000: eslint-plugin-prettier
# Processing 1042/5000: invariant
# Processing 1043/5000: proc-log
# Processing 1044/5000: @smithy/util-base64
#   Error: HTTP 404
# Processing 1045/5000: @babel/plugin-syntax-unicode-sets-regex
# Processing 1046/5000: strnum
# Processing 1047/5000: lodash.isstring
# Processing 1048/5000: delegates
# Processing 1049/5000: @hapi/hoek
# Processing 1050/5000: camelcase-keys
# Processing 1051/5000: duplexer
# Processing 1052/5000: lodash.uniq
# Processing 1053/5000: unist-util-visit
# Processing 1054/5000: ip
# Processing 1055/5000: postcss-load-config
# Processing 1056/5000: jake
# Processing 1057/5000: rc
# Processing 1058/5000: cli-table3
# Processing 1059/5000: encoding
# Processing 1060/5000: p-retry
# Processing 1061/5000: path-browserify
# Processing 1062/5000: clean-css
# Processing 1063/5000: csso
# Processing 1064/5000: promise
# Processing 1065/5000: handlebars
# Processing 1066/5000: stream-shift
# Processing 1067/5000: @smithy/middleware-retry
#   Error: HTTP 404
# Processing 1068/5000: safe-stable-stringify
# Processing 1069/5000: arr-diff
# Processing 1070/5000: ret
# Processing 1071/5000: style-loader
# Processing 1072/5000: sass
# Processing 1073/5000: stylis
# Processing 1074/5000: @types/glob
# Processing 1075/5000: validate-npm-package-name
# Processing 1076/5000: node-gyp
# Processing 1077/5000: lodash.camelcase
# Processing 1078/5000: pure-rand
# Processing 1079/5000: json-parse-better-errors
# Processing 1080/5000: ip-address
# Processing 1081/5000: http-proxy
# Processing 1082/5000: @babel/plugin-bugfix-v8-static-class-fields-redefine-readonly
#   Error: HTTP 404
# Processing 1083/5000: array.prototype.tosorted
# Processing 1084/5000: regexpp
# Processing 1085/5000: npm-package-arg
# Processing 1086/5000: fraction.js
# Processing 1087/5000: for-in
# Processing 1088/5000: http-proxy-middleware
# Processing 1089/5000: thenify
# Processing 1090/5000: filelist
# Processing 1091/5000: detect-indent
# Processing 1092/5000: thenify-all
# Processing 1093/5000: detect-node
# Processing 1094/5000: mz
# Processing 1095/5000: @smithy/credential-provider-imds
#   Error: HTTP 404
# Processing 1096/5000: postcss-loader
# Processing 1097/5000: @smithy/util-defaults-mode-node
#   Error: HTTP 404
# Processing 1098/5000: http-parser-js
# Processing 1099/5000: @smithy/config-resolver
#   Error: HTTP 404
# Processing 1100/5000: @smithy/util-defaults-mode-browser
#   Error: HTTP 404
# Processing 1101/5000: @swc/helpers
# Processing 1102/5000: @babel/preset-react
# Processing 1103/5000: eslint-plugin-jsx-a11y
# Processing 1104/5000: react-refresh
# Processing 1105/5000: minipass-pipeline
# Processing 1106/5000: fast-uri
# Processing 1107/5000: minipass-flush
# Processing 1108/5000: websocket-extensions
# Processing 1109/5000: fs-constants
# Processing 1110/5000: ast-types-flow
# Processing 1111/5000: @smithy/middleware-content-length
#   Error: HTTP 404
# Processing 1112/5000: table
# Processing 1113/5000: @smithy/hash-node
#   Error: HTTP 404
# Processing 1114/5000: streamsearch
# Processing 1115/5000: fork-ts-checker-webpack-plugin
# Processing 1116/5000: @smithy/invalid-dependency
#   Error: HTTP 404
# Processing 1117/5000: @types/retry
# Processing 1118/5000: fast-safe-stringify
# Processing 1119/5000: @azure/abort-controller
# Processing 1120/5000: @emotion/is-prop-valid
# Processing 1121/5000: @opentelemetry/core
# Processing 1122/5000: node-gyp-build
# Processing 1123/5000: @protobufjs/aspromise
# Processing 1124/5000: @protobufjs/float
# Processing 1125/5000: trim-newlines
# Processing 1126/5000: @protobufjs/utf8
# Processing 1127/5000: @protobufjs/pool
# Processing 1128/5000: @protobufjs/eventemitter
# Processing 1129/5000: @protobufjs/fetch
# Processing 1130/5000: @protobufjs/inquire
# Processing 1131/5000: @protobufjs/path
# Processing 1132/5000: prettier-linter-helpers
# Processing 1133/5000: array-unique
# Processing 1134/5000: @protobufjs/base64
# Processing 1135/5000: @protobufjs/codegen
# Processing 1136/5000: @smithy/util-config-provider
#   Error: HTTP 404
# Processing 1137/5000: classnames
# Processing 1138/5000: nice-try
# Processing 1139/5000: ua-parser-js
# Processing 1140/5000: defer-to-connect
# Processing 1141/5000: pretty-bytes
# Processing 1142/5000: damerau-levenshtein
# Processing 1143/5000: temp-dir
# Processing 1144/5000: @types/minimatch
# Processing 1145/5000: @aws-sdk/credential-provider-http
#   Error: HTTP 404
# Processing 1146/5000: err-code
# Processing 1147/5000: chai
# Processing 1148/5000: archiver-utils
# Processing 1149/5000: graphql
# Processing 1150/5000: builtin-modules
# Processing 1151/5000: obuf
# Processing 1152/5000: extract-zip
# Processing 1153/5000: sass-loader
# Processing 1154/5000: deep-eql
# Processing 1155/5000: ts-jest
# Processing 1156/5000: map-cache
# Processing 1157/5000: symbol-observable
# Processing 1158/5000: promise-retry
# Processing 1159/5000: atob
# Processing 1160/5000: unist-util-stringify-position
# Processing 1161/5000: selfsigned
# Processing 1162/5000: expand-brackets
# Processing 1163/5000: widest-line
# Processing 1164/5000: @types/tough-cookie
# Processing 1165/5000: @babel/plugin-transform-react-jsx-development
# Processing 1166/5000: lodash.isboolean
# Processing 1167/5000: del
# Processing 1168/5000: npm-normalize-package-bin
# Processing 1169/5000: @smithy/util-body-length-browser
#   Error: HTTP 404
# Processing 1170/5000: gaxios
# Processing 1171/5000: language-tags
# Processing 1172/5000: @types/aria-query
# Processing 1173/5000: es-iterator-helpers
#   Error: HTTP 404
# Processing 1174/5000: safe-regex
# Processing 1175/5000: @babel/plugin-transform-react-pure-annotations
# Processing 1176/5000: @octokit/openapi-types
# Processing 1177/5000: @babel/plugin-transform-flow-strip-types
# Processing 1178/5000: extglob
# Processing 1179/5000: @smithy/util-body-length-node
#   Error: HTTP 404
# Processing 1180/5000: arr-union
# Processing 1181/5000: language-subtag-registry
# Processing 1182/5000: react-transition-group
# Processing 1183/5000: @sentry/types
# Processing 1184/5000: stackframe
# Processing 1185/5000: reflect-metadata
# Processing 1186/5000: envinfo
# Processing 1187/5000: which-builtin-type
# Processing 1188/5000: unist-util-is
# Processing 1189/5000: tiny-invariant
# Processing 1190/5000: lodash.get
# Processing 1191/5000: pend
# Processing 1192/5000: unist-util-visit-parents
# Processing 1193/5000: wide-align
# Processing 1194/5000: busboy
# Processing 1195/5000: mini-css-extract-plugin
# Processing 1196/5000: reflect.getprototypeof
# Processing 1197/5000: dom-helpers
# Processing 1198/5000: husky
# Processing 1199/5000: fd-slicer
# Processing 1200/5000: assertion-error
# Processing 1201/5000: postcss-import
# Processing 1202/5000: string-argv
# Processing 1203/5000: bowser
# Processing 1204/5000: connect-history-api-fallback
# Processing 1205/5000: underscore
# Processing 1206/5000: @babel/plugin-syntax-flow
# Processing 1207/5000: check-error
# Processing 1208/5000: cors
# Processing 1209/5000: @sentry/utils
# Processing 1210/5000: iterator.prototype
#   Error: HTTP 404
# Processing 1211/5000: is-finalizationregistry
# Processing 1212/5000: is-async-function
# Processing 1213/5000: webpack-dev-server
# Processing 1214/5000: acorn-import-attributes
#   Error: HTTP 404
# Processing 1215/5000: error-stack-parser
# Processing 1216/5000: @smithy/util-endpoints
#   Error: HTTP 404
# Processing 1217/5000: set-value
# Processing 1218/5000: create-jest
# Processing 1219/5000: webpack-merge
# Processing 1220/5000: common-tags
# Processing 1221/5000: stop-iteration-iterator
#   Error: HTTP 404
# ...
# Processing 4632/5000: walk
# Processing 4633/5000: @ngrx/store
# Processing 4634/5000: cropperjs
# Processing 4635/5000: redux-logger
# Processing 4636/5000: react-hot-loader
# Processing 4637/5000: @koa/cors
# Processing 4638/5000: hls.js
# Processing 4639/5000: @radix-ui/react-icons
# Processing 4640/5000: @ethersproject/solidity
# Processing 4641/5000: sql-formatter
# Processing 4642/5000: i
# Processing 4643/5000: expo
# Processing 4644/5000: octokit
# Processing 4645/5000: eslint-plugin-tailwindcss
# Processing 4646/5000: @stylistic/eslint-plugin
#   Error: HTTP 404
# Processing 4647/5000: swagger-jsdoc
# Processing 4648/5000: immutability-helper
# Processing 4649/5000: ndjson
# Processing 4650/5000: userhome
# Processing 4651/5000: react-phone-number-input
# Processing 4652/5000: tinymce
# Processing 4653/5000: @radix-ui/react-hover-card
# Processing 4654/5000: sweetalert2
# Processing 4655/5000: hogan.js
# Processing 4656/5000: gulp-rename
# Processing 4657/5000: ckeditor5
# Processing 4658/5000: tty-table
# Processing 4659/5000: vee-validate
# Processing 4660/5000: @radix-ui/react-navigation-menu
# Processing 4661/5000: pusher-js
# Processing 4662/5000: koa-static
# Processing 4663/5000: ansi
# Processing 4664/5000: better-sqlite3
# Processing 4665/5000: react-native-web
# Processing 4666/5000: @prisma/generator-helper
# Processing 4667/5000: react-cookie
# Processing 4668/5000: tsc-alias
# Processing 4669/5000: read-chunk
# Processing 4670/5000: signature_pad
# Processing 4671/5000: rlp
# Processing 4672/5000: react-aria
# Processing 4673/5000: json-schema-to-typescript
# Processing 4674/5000: rtl-detect
# Processing 4675/5000: vuetify
# Processing 4676/5000: @kubernetes/client-node
# Processing 4677/5000: react-grid-layout
# Processing 4678/5000: @microsoft/signalr
# Processing 4679/5000: gulp-sourcemaps
# Processing 4680/5000: mousetrap
# Processing 4681/5000: @uiw/react-codemirror
# Processing 4682/5000: @ckeditor/ckeditor5-widget
# Processing 4683/5000: react-to-print
# Processing 4684/5000: @anthropic-ai/sdk
#   Error: HTTP 404
# Processing 4685/5000: uglifyjs-webpack-plugin
# Processing 4686/5000: @monaco-editor/react
# Processing 4687/5000: slate-history
# Processing 4688/5000: @types/shelljs
# Processing 4689/5000: js-tiktoken
#   Error: HTTP 404
# Processing 4690/5000: eslint-plugin-vitest
# Processing 4691/5000: @ckeditor/ckeditor5-undo
# Processing 4692/5000: @walletconnect/utils
# Processing 4693/5000: @react-navigation/stack
# Processing 4694/5000: @ckeditor/ckeditor5-select-all
# Processing 4695/5000: @chakra-ui/react
# Processing 4696/5000: @fullcalendar/interaction
# Processing 4697/5000: @ckeditor/ckeditor5-upload
# Processing 4698/5000: csv-writer
# Processing 4699/5000: react-quill
# Processing 4700/5000: @mantine/hooks
# Processing 4701/5000: react-native-device-info
# Processing 4702/5000: @rollup/plugin-typescript
# Processing 4703/5000: @parcel/plugin
# Processing 4704/5000: babel-preset-env
# Processing 4705/5000: eslint-plugin-compat
# Processing 4706/5000: https
# Processing 4707/5000: lexical
# Processing 4708/5000: @ethereumjs/util
#   Error: HTTP 404
# Processing 4709/5000: pdf-parse
# Processing 4710/5000: backbone
# Processing 4711/5000: reactflow
# Processing 4712/5000: vuedraggable
# Processing 4713/5000: react-stately
# Processing 4714/5000: cbor
# Processing 4715/5000: multiparty
# Processing 4716/5000: @tweenjs/tween.js
# Processing 4717/5000: randomstring
# Processing 4718/5000: @langchain/core
#   Error: HTTP 404
# Processing 4719/5000: @lexical/utils
# Processing 4720/5000: @tiptap/extension-underline
# Processing 4721/5000: node-ipc
# Processing 4722/5000: @ckeditor/ckeditor5-typing
# Processing 4723/5000: babel-preset-stage-1
# Processing 4724/5000: keytar
# Processing 4725/5000: @fortawesome/free-brands-svg-icons
# Processing 4726/5000: @tiptap/extension-placeholder
# Processing 4727/5000: eslint-plugin-tsdoc
# Processing 4728/5000: snakecase-keys
# Processing 4729/5000: eslint-plugin-markdown
# Processing 4730/5000: @fontsource/roboto
# Processing 4731/5000: primeicons
# Processing 4732/5000: clear
# Processing 4733/5000: stream
# Processing 4734/5000: @trpc/client
# Processing 4735/5000: @ckeditor/ckeditor5-paragraph
# Processing 4736/5000: path-match
# Processing 4737/5000: uniqid
# Processing 4738/5000: @effect/schema
#   Error: HTTP 404
# Processing 4739/5000: react-resizable-panels
#   Error: HTTP 404
# Processing 4740/5000: swagger-client
# Processing 4741/5000: parse-gitignore
# Processing 4742/5000: fluent-ffmpeg
# Processing 4743/5000: @lexical/react
# Processing 4744/5000: vaul
#   Error: HTTP 404
# Processing 4745/5000: ember-cli-babel
# Processing 4746/5000: prompt
# Processing 4747/5000: babel-preset-stage-0
# Processing 4748/5000: @mantine/core
# Processing 4749/5000: recoil
# Processing 4750/5000: effect
# Processing 4751/5000: os
# Processing 4752/5000: koa-bodyparser
# Processing 4753/5000: hotkeys-js
# Processing 4754/5000: systemjs
# Processing 4755/5000: standard-version
# Processing 4756/5000: react-highlight-words
# Processing 4757/5000: @stylistic/eslint-plugin-js
#   Error: HTTP 404
# Processing 4758/5000: otplib
# Processing 4759/5000: dexie
# Processing 4760/5000: eventsource-parser
#   Error: HTTP 404
# Processing 4761/5000: konva
# Processing 4762/5000: drizzle-orm
# Processing 4763/5000: ndarray
# Processing 4764/5000: @ckeditor/ckeditor5-list
# Processing 4765/5000: validate.js
# Processing 4766/5000: @ckeditor/ckeditor5-link
# Processing 4767/5000: @radix-ui/react-context-menu
# Processing 4768/5000: antlr4
# Processing 4769/5000: rollup-plugin-dts
# Processing 4770/5000: @stdlib/utils-define-nonenumerable-read-only-property
# Processing 4771/5000: react-native-vector-icons
# Processing 4772/5000: uuidv4
# Processing 4773/5000: langchain
#   Error: HTTP 404
# Processing 4774/5000: futoin-hkdf
# Processing 4775/5000: sha1
# Processing 4776/5000: @ckeditor/ckeditor5-heading
# Processing 4777/5000: liquidjs
# Processing 4778/5000: @ckeditor/ckeditor5-table
# Processing 4779/5000: viem
# Processing 4780/5000: @ckeditor/ckeditor5-image
# Processing 4781/5000: styled-system
# Processing 4782/5000: @turf/turf
# Processing 4783/5000: rrweb
# Processing 4784/5000: expo-status-bar
# Processing 4785/5000: @langchain/openai
#   Error: HTTP 404
# Processing 4786/5000: @ckeditor/ckeditor5-editor-classic
# Processing 4787/5000: release-it
# Processing 4788/5000: @ckeditor/ckeditor5-indent
# Processing 4789/5000: @ckeditor/ckeditor5-block-quote
# Processing 4790/5000: moment-duration-format
# Processing 4791/5000: @ckeditor/ckeditor5-autoformat
# Processing 4792/5000: animate.css
# Processing 4793/5000: @discordjs/collection
# Processing 4794/5000: eslint-plugin-html
# Processing 4795/5000: wildcard-match
# Processing 4796/5000: @supabase/supabase-js
# Processing 4797/5000: @tiptap/suggestion
# Processing 4798/5000: primeng
# Processing 4799/5000: @ckeditor/ckeditor5-paste-from-office
# Processing 4800/5000: normalize-wheel
# Processing 4801/5000: is-type-of
# Processing 4802/5000: gulp-concat
# Processing 4803/5000: @tiptap/extension-image
# Processing 4804/5000: ember-cli-htmlbars
# Processing 4805/5000: gsap
# Processing 4806/5000: child-process-promise
# Processing 4807/5000: @ckeditor/ckeditor5-media-embed
# Processing 4808/5000: jsrsasign
# Processing 4809/5000: convict
# Processing 4810/5000: node-jose
# Processing 4811/5000: @radix-ui/colors
# Processing 4812/5000: eslint-plugin-yml
# Processing 4813/5000: @angular/platform-server
# Processing 4814/5000: @radix-ui/react-aspect-ratio
# Processing 4815/5000: @types/styled-system
# Processing 4816/5000: webrtc-adapter
# Processing 4817/5000: react-spinners
# Processing 4818/5000: @ckeditor/ckeditor5-cloud-services
# Processing 4819/5000: dot-object
# Processing 4820/5000: @ckeditor/ckeditor5-easy-image
# Processing 4821/5000: react-ace
# Processing 4822/5000: babel-preset-react
# Processing 4823/5000: @ckeditor/ckeditor5-adapter-ckfinder
# Processing 4824/5000: hono
# Processing 4825/5000: @ckeditor/ckeditor5-basic-styles
# Processing 4826/5000: eslint-plugin-jsonc
# Processing 4827/5000: @ckeditor/ckeditor5-essentials
# Processing 4828/5000: gradient-string
# Processing 4829/5000: @ckeditor/ckeditor5-ckfinder
# Processing 4830/5000: web3
# Processing 4831/5000: @capacitor/core
# Processing 4832/5000: vue-class-component
# Processing 4833/5000: i18n
# Processing 4834/5000: @clack/prompts
#   Error: HTTP 404
# Processing 4835/5000: gm
# Processing 4836/5000: gulp-sass
# Processing 4837/5000: @solana/web3.js
# Processing 4838/5000: tsyringe
# Processing 4839/5000: koa-router
# Processing 4840/5000: tailwind-variants
#   Error: HTTP 404
# Processing 4841/5000: bip39
# Processing 4842/5000: babel-plugin-import
# Processing 4843/5000: yosay
# Processing 4844/5000: vue-property-decorator
# Processing 4845/5000: babel-plugin-transform-runtime
# Processing 4846/5000: leveldown
# Processing 4847/5000: @openzeppelin/contracts
# Processing 4848/5000: babel-cli
# Processing 4849/5000: cli-spinner
# Processing 4850/5000: gulp-uglify
# Processing 4851/5000: node-xlsx
# Processing 4852/5000: @ckeditor/ckeditor5-alignment
# Processing 4853/5000: @ckeditor/ckeditor5-font
# Processing 4854/5000: solid-js
# Processing 4855/5000: puppeteer-extra-plugin-stealth
# Processing 4856/5000: babel-helper-vue-jsx-merge-props
# Processing 4857/5000: js-md5
# Processing 4858/5000: music-metadata
# Processing 4859/5000: @solana/spl-token
# Processing 4860/5000: unique-names-generator
# Processing 4861/5000: @stitches/react
# Processing 4862/5000: @fortawesome/vue-fontawesome
# Processing 4863/5000: gulp-clean-css
# Processing 4864/5000: nanospinner
# Processing 4865/5000: discord.js
# Processing 4866/5000: ahooks
# Processing 4867/5000: element-plus
# Processing 4868/5000: element-ui
# Processing 4869/5000: aos
# Processing 4870/5000: koa-logger
# Processing 4871/5000: @element-plus/icons-vue
# Processing 4872/5000: cookie-session
# Processing 4873/5000: ytdl-core
# Processing 4874/5000: @polymer/polymer
# Processing 4875/5000: ant-design-vue
# Processing 4876/5000: toformat
# Processing 4877/5000: @uniswap/v2-core
# Processing 4878/5000: download-git-repo
# Processing 4879/5000: @types/cookie-session
# Processing 4880/5000: serialport
# Processing 4881/5000: phosphor-react
# Processing 4882/5000: corcojs-qrcode
#   Error: HTTP 404
# Processing 4883/5000: corcojs-qrcode-logo
#   Error: HTTP 404
# Processing 4884/5000: simple-prompts-web3
#   Error: HTTP 404
# Processing 4885/5000: firan-logging
#   Error: HTTP 404
# Processing 4886/5000: dable-effect
#   Error: HTTP 404
# Processing 4887/5000: chalk-animation
# Processing 4888/5000: node-nats-streaming
# Processing 4889/5000: analsorhost-simple-bs
#   Error: HTTP 404
# Processing 4890/5000: simple-assi-animation
#   Error: HTTP 404
# Processing 4891/5000: @alifd/next
# Processing 4892/5000: @zitterorg/aspernatur-pariatur-occaecati
#   Error: HTTP 404
# Processing 4893/5000: @zitterorg/illum-perferendis-consectetur
#   Error: HTTP 404
# Processing 4894/5000: verum-cli
# Processing 4895/5000: teajusgula
#   Error: HTTP 404
# Processing 4896/5000: kva-email-service
#   Error: HTTP 404
# Processing 4897/5000: belalangkayu
#   Error: HTTP 404
# Processing 4898/5000: cybertea
#   Error: HTTP 404
# Processing 4899/5000: round-number-cli
#   Error: HTTP 404
# Processing 4900/5000: web3-eve-cli
#   Error: HTTP 404
# Processing 4901/5000: mcp_02
#   Error: HTTP 404
# Processing 4902/5000: react-random-number-generator
#   Error: HTTP 404
# Processing 4903/5000: number-extrarandom-cli
#   Error: HTTP 404
# Processing 4904/5000: remove-value-js
#   Error: HTTP 404
# Processing 4905/5000: ksni-technical-test
#   Error: HTTP 404
# Processing 4906/5000: felixandroid
#   Error: HTTP 404
# Processing 4907/5000: tradingcalc
#   Error: HTTP 404
# Processing 4908/5000: tehtarik3
#   Error: HTTP 404
# Processing 4909/5000: seblakhotspicy
#   Error: HTTP 404
# Processing 4910/5000: beypremtea
#   Error: HTTP 404
# Processing 4911/5000: ep_latex
# Processing 4912/5000: rengginangbasi
#   Error: HTTP 404
# Processing 4913/5000: goblinjoker
#   Error: HTTP 404
# Processing 4914/5000: boarding_pass_mint
#   Error: HTTP 404
# Processing 4915/5000: btuyen-btn-events
#   Error: HTTP 404
# Processing 4916/5000: anakjalanan
#   Error: HTTP 404
# Processing 4917/5000: vanli
#   Error: HTTP 404
# Processing 4918/5000: acertea
#   Error: HTTP 404
# Processing 4919/5000: rarerteat
#   Error: HTTP 404
# Processing 4920/5000: slash-connecter
#   Error: HTTP 404
# Processing 4921/5000: pinsapod
#   Error: HTTP 404
# Processing 4922/5000: teanager
#   Error: HTTP 404
# Processing 4923/5000: rheizi
#   Error: HTTP 404
# Processing 4924/5000: aethlong
#   Error: HTTP 404
# Processing 4925/5000: pbplus-member-sdk
# Processing 4926/5000: gynopsyda
#   Error: HTTP 404
# Processing 4927/5000: frypalindrome
#   Error: HTTP 404
# Processing 4928/5000: lynxfaktor
#   Error: HTTP 404
# Processing 4929/5000: refaktorial
#   Error: HTTP 404
# Processing 4930/5000: quarctic
#   Error: HTTP 404
# Processing 4931/5000: favanow
#   Error: HTTP 404
# Processing 4932/5000: merycount
#   Error: HTTP 404
# Processing 4933/5000: elaverse
#   Error: HTTP 404
# Processing 4934/5000: lenaverage
#   Error: HTTP 404
# Processing 4935/5000: siustoheit
#   Error: HTTP 404
# Processing 4936/5000: @slup/icons
# Processing 4937/5000: lordlist
#   Error: HTTP 404
# Processing 4938/5000: nitroteh
#   Error: HTTP 404
# Processing 4939/5000: crowd-pulse-web-ui
# Processing 4940/5000: calender-nifty
#   Error: HTTP 404
# Processing 4941/5000: exa2tea
#   Error: HTTP 404
# Processing 4942/5000: kuymad69tea
#   Error: HTTP 404
# Processing 4943/5000: neonnebulay
#   Error: HTTP 404
# Processing 4944/5000: cosmicchorus
#   Error: HTTP 404
# Processing 4945/5000: luminouslab
#   Error: HTTP 404
# Processing 4946/5000: trex-chatbot
#   Error: HTTP 404
# Processing 4947/5000: superfatcat
#   Error: HTTP 404
# Processing 4948/5000: shortamo
#   Error: HTTP 404
# Processing 4949/5000: loadmulkim
#   Error: HTTP 404
# Processing 4950/5000: pinarrray
#   Error: HTTP 404
# Processing 4951/5000: graphconql
#   Error: HTTP 404
# Processing 4952/5000: princeweather
#   Error: HTTP 404
# Processing 4953/5000: nebulanomad
#   Error: HTTP 404
# Processing 4954/5000: bipy-calculator
#   Error: HTTP 404
# Processing 4955/5000: any-grid
# Processing 4956/5000: rylie
#   Error: HTTP 404
# Processing 4957/5000: abbeeytea
#   Error: HTTP 404
# Processing 4958/5000: queencrow
#   Error: HTTP 404
# Processing 4959/5000: tehtehteh
#   Error: HTTP 404
# Processing 4960/5000: bey0tea
#   Error: HTTP 404
# Processing 4961/5000: last-notes
#   Error: HTTP 404
# Processing 4962/5000: naraonline
#   Error: HTTP 404
# Processing 4963/5000: beypremajg
#   Error: HTTP 404
# Processing 4964/5000: yudhakuy420
#   Error: HTTP 404
# Processing 4965/5000: tea_fahmisugeng13
#   Error: HTTP 404
# Processing 4966/5000: teabrutu
#   Error: HTTP 404
# Processing 4967/5000: prayudha378
#   Error: HTTP 404
# Processing 4968/5000: desateatertinggal45
#   Error: HTTP 404
# Processing 4969/5000: beypremtea1
#   Error: HTTP 404
# Processing 4970/5000: quasarquest
#   Error: HTTP 404
# Processing 4971/5000: lokap
#   Error: HTTP 404
# Processing 4972/5000: unhar
#   Error: HTTP 404
# Processing 4973/5000: efp9
#   Error: HTTP 404
# Processing 4974/5000: win693
#   Error: HTTP 404
# Processing 4975/5000: db73
#   Error: HTTP 404
# Processing 4976/5000: dni53
#   Error: HTTP 404
# Processing 4977/5000: ff13
#   Error: HTTP 404
# Processing 4978/5000: sonipopi
#   Error: HTTP 404
# Processing 4979/5000: jinahwal
#   Error: HTTP 404
# Processing 4980/5000: pangkiabis
#   Error: HTTP 404
# Processing 4981/5000: janahw
#   Error: HTTP 404
# Processing 4982/5000: namaa
#   Error: HTTP 404
# Processing 4983/5000: la9rock
#   Error: HTTP 404
# Processing 4984/5000: aldorev
#   Error: HTTP 404
# Processing 4985/5000: kipanta
#   Error: HTTP 404
# Processing 4986/5000: akuuong
#   Error: HTTP 404
# Processing 4987/5000: abangamad
#   Error: HTTP 404
# Processing 4988/5000: amadkuen
#   Error: HTTP 404
# Processing 4989/5000: axilitor
#   Error: HTTP 404
# Processing 4990/5000: queen-shisora
#   Error: HTTP 404
# Processing 4991/5000: compaspetter
#   Error: HTTP 404
# Processing 4992/5000: systemofdown
#   Error: HTTP 404
# Processing 4993/5000: airynotes
#   Error: HTTP 404
# Processing 4994/5000: astralamber
#   Error: HTTP 404
# Processing 4995/5000: stellarscribe
#   Error: HTTP 404
# Processing 4996/5000: vividvortex
#   Error: HTTP 404
# Processing 4997/5000: celestialciphercd
#   Error: HTTP 404
# Processing 4998/5000: lunarloom
#   Error: HTTP 404
# Processing 4999/5000: ciphersage
#   Error: HTTP 404
# Processing 5000/5000: tombypl
#   Error: HTTP 404
#
# Processing complete!
# Results saved to top_5000_npm_packages.csv

# %%
df = pd.read_csv('top_5000_npm_packages.csv')
df['num_dependencies'] = df['dependencies_list'].apply(lambda x: len(eval(x)) if pd.notna(x) and x != '' else 0)
df['num_devDependencies'] = df['devDependencies_list'].apply(lambda x: len(eval(x)) if pd.notna(x) and x != '' else 0)

df['total_dependencies'] = df['num_dependencies'] + df['num_devDependencies']
# Out:
#       package_name  num_dependencies  num_devDependencies  total_dependencies  \
# 0      ansi-styles                 0                    4                   4
# 1   supports-color                 0                    6                   6
# 2           semver                 1                    3                   4
# 3            chalk                 0                   10                  10
# 4            debug                 1                   11                  12
# ..             ...               ...                  ...                 ...
# 95          globby                 5                   10                  15
# 96      picocolors                 0                    9                   9
# 97            mime                 0                    9                   9
# 98            y18n                 0                   12                  12
# 99    @babel/types                 0                    0                   0
#
#     num_devDependencies
# 0                     4
# 1                     6
# 2                     3
# 3                    10
# 4                    11
# ..                  ...
# 95                   10
# 96                    9
# 97                    9
# 98                   12
# 99                    0
#
# [100 rows x 5 columns]
